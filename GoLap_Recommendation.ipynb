# %% [markdown]
# ## Import Libraries

# %%
import re
import pandas as pd
import matplotlib.pyplot as plt
from IPython.display import Image, display
from sklearn.metrics.pairwise import linear_kernel, cosine_similarity
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer

# %% [markdown]
# ## Import Dataset

# %%
df = pd.read_csv('../Dataset/Golap_Dataset_Final.csv')

df.head()
# Out:
#    Laptop_Index                                    Link_References  \
# 0             1  https://www.flipkart.com/acer-aspire-3-core-i3...
# 1             2  https://www.flipkart.com/acer-aspire-3-core-i3...
# 2             3  https://www.flipkart.com/acer-aspire-3-core-i5...
# 3             4  https://www.flipkart.com/acer-aspire-3-core-i5...
# 4             5  https://www.flipkart.com/acer-aspire-3-core-i5...
#
#                               Laptop_Name  User_Rating  Price_in_IDR  \
# 0  acer aspire 3 core i3 11th gen_type(1)          4.2       6587512
# 1  acer aspire 3 core i3 11th gen_type(2)          NaN       7338698
# 2  acer aspire 3 core i5 10th gen_type(1)          3.2       8656238
# 3  acer aspire 3 core i5 11th gen_type(1)          NaN       9220898
# 4  acer aspire 3 core i5 11th gen_type(2)          NaN       9390296
#
#    Laptop_Type  Dedicated_GPU_in_GB  Processor_Brand  Storage_Type  RAM_in_GB  \
# 0            2                    0                1             1          4
# 1            2                    0                1             1          8
# 2            4                    2                1             0          8
# 3            2                    0                1             0          8
# 4            2                    0                1             1          8
#
#    ... Laptop_Company  Storage_Capacity               Processor  CPU_Rank  \
# 0  ...              8               256  intel core i3 11th gen       362
# 1  ...              8               512  intel core i3 11th gen       362
# 2  ...              8              1000  intel core i5 10th gen       187
# 3  ...              8              1000  intel core i5 11th gen       108
# 4  ...              8               512  intel core i5 11th gen       108
#
#    Battery_Lifetime_in_Hrs                        GPU  GPU_Benchmark_Score  \
# 0                      4.5                  intel uhd                 5.05
# 1                      4.5                  intel uhd                 5.05
# 2                      4.5  nvidia geforce gtx mx 330                16.50
# 3                      4.5                    iris xe                17.50
# 4                      4.5              intel iris xe                17.50
#
#    RAM_Type_Tokenized  GPU_Processor_Tokenized  \
# 0                   4                        7
# 1                   4                        7
# 2                   4                       57
# 3                   4                        4
# 4                   4                        8
#
#                                           Image_Link
# 0  https://rukminim2.flixcart.com/image/416/416/k...
# 1  https://rukminim2.flixcart.com/image/416/416/l...
# 2  https://rukminim2.flixcart.com/image/416/416/k...
# 3  https://rukminim2.flixcart.com/image/416/416/l...
# 4  https://rukminim2.flixcart.com/image/416/416/x...
#
# [5 rows x 28 columns]

# %% [markdown]
# ## Exploratory Data Analysis

# %%
df.shape
# Out:
# (983, 28)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 983 entries, 0 to 982
# Data columns (total 28 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Laptop_Index             983 non-null    int64
#  1   Link_References          983 non-null    object
#  2   Laptop_Name              983 non-null    object
#  3   User_Rating              689 non-null    float64
#  4   Price_in_IDR             983 non-null    int64
#  5   Laptop_Type              983 non-null    int64
#  6   Dedicated_GPU_in_GB      983 non-null    int64
#  7   Processor_Brand          983 non-null    int64
#  8   Storage_Type             983 non-null    int64
#  9   RAM_in_GB                983 non-null    int64
#  10  RAM_Type                 983 non-null    object
#  11  Memory_Type              983 non-null    int64
#  12  OS                       983 non-null    int64
#  13  Touchscreen_Features     983 non-null    int64
#  14  Screen_Size_in_Inch      983 non-null    float64
#  15  Weight_in_Kg             983 non-null    float64
#  16  Refresh_Rate             983 non-null    int64
#  17  Screen_Resolution        983 non-null    int64
#  18  Laptop_Company           983 non-null    int64
#  19  Storage_Capacity         983 non-null    int64
#  20  Processor                983 non-null    object
#  21  CPU_Rank                 983 non-null    int64
#  22  Battery_Lifetime_in_Hrs  983 non-null    float64
#  23  GPU                      983 non-null    object
#  24  GPU_Benchmark_Score      983 non-null    float64
#  25  RAM_Type_Tokenized       983 non-null    int64
#  26  GPU_Processor_Tokenized  983 non-null    int64
#  27  Image_Link               983 non-null    object
# dtypes: float64(5), int64(17), object(6)
# memory usage: 215.2+ KB

# %%
df.describe()
# Out:
#        Laptop_Index  User_Rating  Price_in_IDR  Laptop_Type  \
# count    983.000000    689.00000  9.830000e+02   983.000000
# mean     492.000000      4.20508  1.311549e+07     2.155646
# std      283.911958      0.44629  7.218815e+06     0.963270
# min        1.000000      1.80000  3.009638e+06     1.000000
# 25%      246.500000      4.00000  8.180042e+06     2.000000
# 50%      492.000000      4.30000  1.129132e+07     2.000000
# 75%      737.500000      4.50000  1.547630e+07     2.000000
# max      983.000000      5.00000  5.684056e+07     4.000000
#
#        Dedicated_GPU_in_GB  Processor_Brand  Storage_Type   RAM_in_GB  \
# count           983.000000       983.000000     983.00000  983.000000
# mean              2.101729         1.321465       0.89115   10.400814
# std              17.395069         0.565845       0.31161    4.910407
# min               0.000000         1.000000       0.00000    4.000000
# 25%               0.000000         1.000000       1.00000    8.000000
# 50%               0.000000         1.000000       1.00000    8.000000
# 75%               4.000000         2.000000       1.00000   16.000000
# max             512.000000         5.000000       1.00000   32.000000
#
#        Memory_Type          OS  ...  Weight_in_Kg  Refresh_Rate  \
# count   983.000000  983.000000  ...  9.830000e+02     983.00000
# mean      0.388606    1.074262  ...  1.536776e+06      50.86470
# std       0.487682    0.413099  ...  4.786475e+07      20.98751
# min       0.000000    1.000000  ...  7.800000e-01       1.00000
# 25%       0.000000    1.000000  ...  1.490000e+00      60.00000
# 50%       0.000000    1.000000  ...  1.700000e+00      60.00000
# 75%       1.000000    1.000000  ...  2.100000e+00      60.00000
# max       1.000000    5.000000  ...  1.500672e+09      60.00000
#
#        Screen_Resolution  Laptop_Company  Storage_Capacity    CPU_Rank  \
# count         983.000000      983.000000        983.000000  983.000000
# mean         1092.817904        3.255341        648.280773  230.869786
# std           192.147512        2.631648        331.296537  209.558792
# min           720.000000        1.000000         32.000000    4.000000
# 25%          1080.000000        1.000000        512.000000   87.000000
# 50%          1080.000000        3.000000        512.000000  108.000000
# 75%          1080.000000        4.000000       1000.000000  362.000000
# max          2160.000000       16.000000       2000.000000  907.000000
#
#        Battery_Lifetime_in_Hrs  GPU_Benchmark_Score  RAM_Type_Tokenized  \
# count               983.000000           983.000000          983.000000
# mean                  4.415056            40.556439            4.263479
# std                   0.260536            42.464775            0.759702
# min                   4.000000             1.000000            1.000000
# 25%                   4.500000             5.050000            4.000000
# 50%                   4.500000            17.500000            4.000000
# 75%                   4.500000            72.600000            4.000000
# max                   5.000000           233.000000            8.000000
#
#        GPU_Processor_Tokenized
# count               983.000000
# mean                 10.149542
# std                  10.354069
# min                   1.000000
# 25%                   5.000000
# 50%                   7.000000
# 75%                   8.500000
# max                  62.000000
#
# [8 rows x 22 columns]

# %%
df.isna().sum()
# Out:
# Laptop_Index                 0
# Link_References              0
# Laptop_Name                  0
# User_Rating                294
# Price_in_IDR                 0
# Laptop_Type                  0
# Dedicated_GPU_in_GB          0
# Processor_Brand              0
# Storage_Type                 0
# RAM_in_GB                    0
# RAM_Type                     0
# Memory_Type                  0
# OS                           0
# Touchscreen_Features         0
# Screen_Size_in_Inch          0
# Weight_in_Kg                 0
# Refresh_Rate                 0
# Screen_Resolution            0
# Laptop_Company               0
# Storage_Capacity             0
# Processor                    0
# CPU_Rank                     0
# Battery_Lifetime_in_Hrs      0
# GPU                          0
# GPU_Benchmark_Score          0
# RAM_Type_Tokenized           0
# GPU_Processor_Tokenized      0
# Image_Link                   0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ## Data Preprocessing

# %% [markdown]
# #### Changing currency features

# %% [markdown]
# ###### change currency from india rupee to indonesian rupiah

# %%
# df.rename(columns={'Price_in_Rupee': 'Price_in_IDR'}, inplace=True)

# exchange_rate_rupee_to_rupiah = 188.37

# df['Price_in_IDR'] = df['Price_in_IDR'] * exchange_rate_rupee_to_rupiah

# %%
# df['Price_in_IDR']

# %% [markdown]
# #### Untokenized the tokenized features

# %% [markdown]
# ###### untokenized laptop type features

# %%
laptop_type_mapping = {
    1: 'Gaming Laptop',
    2: 'Thin and Light Laptop',
    3: '2 in 1 Laptop',
    4: 'Notebook',
    5: 'Normal Laptop',
    6: '2 in 1 Gaming Laptop',
    7: 'Business Laptop',
    8: 'Chromebook',
    9: 'Creator Laptop'
}

df['Laptop_Type'] = df['Laptop_Type'].map(laptop_type_mapping)

# %%
df['Laptop_Type'].unique()
# Out:
# array(['Thin and Light Laptop', 'Notebook', 'Gaming Laptop',
#        '2 in 1 Laptop'], dtype=object)

# %% [markdown]
# ###### untokenized processor brand features

# %%
processor_brand_mapping = {
    1: 'Intel',
    2: 'AMD',
    3: 'Qualcomm',
    4: 'Apple',
    5: 'Mediatek'
}

df['Processor_Brand'] = df['Processor_Brand'].map(processor_brand_mapping)

# %%
df['Processor_Brand'].unique()
# Out:
# array(['Intel', 'AMD', 'Apple', 'Mediatek', 'Qualcomm'], dtype=object)

# %% [markdown]
# ###### untokenized storage type features

# %%
storage_type_mapping = {
    0: 'HDD',
    1: 'SSD'
}

df['Storage_Type'] = df['Storage_Type'].map(storage_type_mapping)

# %%
df['Storage_Type'].unique()
# Out:
# array(['SSD', 'HDD'], dtype=object)

# %% [markdown]
# ###### untokenized memory type features

# %%
memory_type_mapping = {
    0: 'Non Expandable',
    1: 'Expandable'
}

df['Memory_Type'] = df['Memory_Type'].map(memory_type_mapping)

# %%
df['Memory_Type'].unique()
# Out:
# array(['Expandable', 'Non Expandable'], dtype=object)

# %% [markdown]
# ###### untokenized operating system features

# %%
os_mapping = {
    1: 'Windows',
    2: 'Chrome OS',
    3: 'Dos',
    4: 'Mac',
    5: 'Ubuntu'
}

df['OS'] = df['OS'].map(os_mapping)

# %%
df['OS'].unique()
# Out:
# array(['Windows', 'Mac', 'Chrome OS', 'Dos', 'Ubuntu'], dtype=object)

# %% [markdown]
# ###### untokenized touchsreen features

# %%
touchscreen_mapping = {
    0: 'Non Touchscreen',
    1: 'Touchsreen'
}

df['Touchscreen_Features'] = df['Touchscreen_Features'].map(touchscreen_mapping)

# %%
df['Touchscreen_Features'].unique()
# Out:
# array(['Non Touchscreen', 'Touchsreen'], dtype=object)

# %% [markdown]
# ###### untokenized laptop company features

# %%
company_mapping = {
    1: "Asus",
    2: "HP",
    3: "Lenovo",
    4: "Dell",
    5: "MSI",
    6: "Realme",
    7: "Avita",
    8: "Acer",
    9: "Samsung",
    10: "Infinix",
    11: "LG",
    12: "Apple",
    13: "Nokia",
    14: "Redmibook",
    15: "MI",
    16: "VAIO"
}

df['Laptop_Company'] = df['Laptop_Company'].map(company_mapping)

# %%
df['Laptop_Company'].unique()
# Out:
# array(['Acer', 'Apple', 'Asus', 'Avita', 'Dell', 'HP', 'Infinix',
#        'Lenovo', 'LG', 'MI', 'MSI', 'Nokia', 'Realme', 'Redmibook',
#        'Samsung', 'VAIO'], dtype=object)

# %% [markdown]
# #### - Handling NaN Value

# %% [markdown]
# ###### user rating features

# %%
df['User_Rating'] = df['User_Rating'].fillna(0)

# %%
df['User_Rating'].isna().sum()
# Out:
# np.int64(0)

# %% [markdown]
# #### Removing Unnecessary Words

# %% [markdown]
# ###### laptop name features for laptop description

# %%
df['Laptop_Name'] = df['Laptop_Name'].str.replace(r'-.*$', '', regex=True)
df['Laptop_Name']
# Out:
# 0             acer aspire 3 core i3 11th gen_type(1)
# 1             acer aspire 3 core i3 11th gen_type(2)
# 2             acer aspire 3 core i5 10th gen_type(1)
# 3             acer aspire 3 core i5 11th gen_type(1)
# 4             acer aspire 3 core i5 11th gen_type(2)
#                            ...
# 978    vaio e series ryzen 5 quad core 3500u_type(1)
# 979    vaio e series ryzen 5 quad core 3500u_type(2)
# 980    vaio e series ryzen 7 quad core 3700u_type(1)
# 981    vaio e series ryzen 7 quad core 3700u_type(2)
# 982           vaio se series core i5 8th gen_type(1)
# Name: Laptop_Name, Length: 983, dtype: object

# %%
def cleaning_name(row):
    keywords = row['Processor'].split()
    pattern = r'\b(' + '|'.join(keywords) + r')\b'
    cleaned_name = re.sub(pattern, '', row['Laptop_Name'], flags=re.IGNORECASE).strip()
    cleaned_name = re.sub(r'\s+', ' ', cleaned_name)
    return cleaned_name

df['Laptop_Name'] = df.apply(cleaning_name, axis=1)
df['Laptop_Name']
# Out:
# 0        acer aspire 3 gen_type(1)
# 1        acer aspire 3 gen_type(2)
# 2        acer aspire 3 gen_type(1)
# 3        acer aspire 3 gen_type(1)
# 4        acer aspire 3 gen_type(2)
#                   ...
# 978    vaio e series 3500u_type(1)
# 979    vaio e series 3500u_type(2)
# 980    vaio e series 3700u_type(1)
# 981    vaio e series 3700u_type(2)
# 982     vaio se series gen_type(1)
# Name: Laptop_Name, Length: 983, dtype: object

# %% [markdown]
# ## Data Visualization

# %%
def pie_plot(features):
    col_counts = features.value_counts()
    plt.figure(figsize=(6, 6))
    plt.pie(col_counts, labels=col_counts.index, autopct='%1.1f%%', startangle=90, colors=plt.cm.Paired.colors)
    plt.title(f'Distribution of {features.name}')
    plt.show()

def scatter_plot(features):
    plt.figure(figsize=(15, 6))
    plt.scatter(features.index, features.values)
    plt.xlabel('Index')
    plt.ylabel(features.name)
    plt.title(f'Scatter plot of {features.name}')
    plt.show()

def histogram_plot(features, bins=10):
    plt.figure(figsize=(15, 6))
    plt.hist(features, bins=bins, color='skyblue', edgecolor='black')
    plt.xlabel(features.name)
    plt.ylabel('Frequency')
    plt.title(f'Histogram of {features.name}')
    plt.show()

# %%
df['Laptop_Name'].value_counts()
# Out:
# Laptop_Name
# asus gen_type(1)                  14
# lenovo gen_type(1)                11
# asus gen_type(2)                   8
# lenovo gen_type(2)                 6
# msi gen_type(1)                    6
#                                   ..
# realme book (slim) gen_type(1)     1
# realme book prime gen_type(1)      1
# acer aspire 3 3500u_type(1)        1
# acer aspire r33250u_type(1)        1
# acer aspire 3250u_type(1)          1
# Name: count, Length: 695, dtype: int64

# %%
df['User_Rating'].value_counts()
# Out:
# User_Rating
# 0.0    294
# 4.3    113
# 4.4     97
# 4.5     86
# 4.2     67
# 4.1     51
# 4.0     40
# 4.6     35
# 4.7     33
# 3.8     24
# 3.9     23
# 3.7     22
# 5.0     18
# 4.8     12
# 3.6     11
# 3.5     10
# 3.0      9
# 3.4      7
# 3.3      7
# 3.2      5
# 2.8      4
# 4.9      3
# 3.1      3
# 2.3      2
# 2.9      2
# 2.0      2
# 2.7      1
# 1.8      1
# 2.5      1
# Name: count, dtype: int64

# %%
scatter_plot(features=df['User_Rating'])

# %%
df['Price_in_IDR'].value_counts()
# Out:
# Price_in_IDR
# 7715138     16
# 7338698     15
# 12232418    14
# 11103098    14
# 10350218    14
#             ..
# 52699718     1
# 48935318     1
# 20419988     1
# 15149828     1
# 15168650     1
# Name: count, Length: 433, dtype: int64

# %%
scatter_plot(features=df['Price_in_IDR'])

# %%
df['Laptop_Type'].value_counts()
# Out:
# Laptop_Type
# Thin and Light Laptop    528
# Gaming Laptop            231
# Notebook                 160
# 2 in 1 Laptop             64
# Name: count, dtype: int64

# %%
pie_plot(features=df['Laptop_Type'])

# %%
df['Dedicated_GPU_in_GB'].value_counts()
# Out:
# Dedicated_GPU_in_GB
# 0      674
# 4      185
# 2       59
# 6       39
# 8       19
# 16       2
# 128      2
# 12       1
# 512      1
# 10       1
# Name: count, dtype: int64

# %%
df['Storage_Type'].value_counts()
# Out:
# Storage_Type
# SSD    876
# HDD    107
# Name: count, dtype: int64

# %%
pie_plot(features=df['Storage_Type'])

# %%
df['RAM_in_GB'].value_counts()
# Out:
# RAM_in_GB
# 8     557
# 16    306
# 4     106
# 32     14
# Name: count, dtype: int64

# %%
pie_plot(features=df['RAM_in_GB'])

# %%
df['RAM_Type'].value_counts()
# Out:
# RAM_Type
# ddr4              855
# lpddr4x            86
# ddr5               20
# lpddr4             14
# lpddr5              4
# lpddr3              2
# unified memory      1
# ddr3                1
# Name: count, dtype: int64

# %%
df['Memory_Type'].value_counts()
# Out:
# Memory_Type
# Non Expandable    601
# Expandable        382
# Name: count, dtype: int64

# %%
pie_plot(features=df['Memory_Type'])

# %%
df['OS'].value_counts()
# Out:
# OS
# Windows      945
# Chrome OS     17
# Mac           12
# Dos            8
# Ubuntu         1
# Name: count, dtype: int64

# %%
pie_plot(features=df['OS'])

# %%
df['Touchscreen_Features'].value_counts()
# Out:
# Touchscreen_Features
# Non Touchscreen    858
# Touchsreen         125
# Name: count, dtype: int64

# %%
pie_plot(features=df['Touchscreen_Features'])

# %%
df['Screen_Size_in_Inch'].value_counts()
# Out:
# Screen_Size_in_Inch
# 15.60    497
# 14.00    321
# 13.30     55
# 11.60     16
# 17.30     16
# 16.10     13
# 13.40     13
# 14.96     12
# 14.10     11
# 16.00      9
# 13.50      4
# 15.00      4
# 13.00      3
# 12.00      2
# 14.20      1
# 15.30      1
# 16.60      1
# 14.90      1
# 14.50      1
# 14.22      1
# 13.60      1
# Name: count, dtype: int64

# %%
df['Weight_in_Kg'].value_counts()
# Out:
# Weight_in_Kg
# 1.800000    114
# 9.974375     66
# 2.300000     43
# 1.400000     38
# 1.300000     38
#            ...
# 2.470000      1
# 2.330000      1
# 2.380000      1
# 1.790000      1
# 1.100000      1
# Name: count, Length: 101, dtype: int64

# %%
scatter_plot(features=df['Weight_in_Kg'])

# %%
df['Refresh_Rate'].value_counts()
# Out:
# Refresh_Rate
# 60    826
# 1      96
# 6      47
# 3       6
# 2       4
# 9       4
# Name: count, dtype: int64

# %%
df['Screen_Resolution'].value_counts()
# Out:
# Screen_Resolution
# 1080    806
# 720      84
# 1440     80
# 2160     13
# Name: count, dtype: int64

# %%
pie_plot(features=df['Screen_Resolution'])

# %%
df['Laptop_Company'].value_counts()
# Out:
# Laptop_Company
# Asus         295
# Dell         188
# Lenovo       184
# HP           152
# Acer          60
# MSI           53
# Apple         12
# Realme         9
# Infinix        8
# VAIO           5
# Avita          4
# Nokia          4
# Redmibook      3
# LG             3
# MI             2
# Samsung        1
# Name: count, dtype: int64

# %%
histogram_plot(features=df['Laptop_Company'])

# %%
df['Storage_Capacity'].value_counts()
# Out:
# Storage_Capacity
# 512     500
# 1000    215
# 256     139
# 1256     88
# 64       16
# 128      11
# 1024      5
# 1512      4
# 2000      3
# 32        1
# 516       1
# Name: count, dtype: int64

# %%
df['Processor'].value_counts()
# Out:
# Processor
# intel core i5 11th gen     224
# intel core i3 11th gen     139
# amd ryzen 5 hexa core       86
# intel core i3 10th gen      76
# intel core i7 11th gen      75
#                           ...
# intel core i5 7th gen        1
# intel core i9 10th gen       1
# intel core i7 9th gen        1
# intel ryzen 7 hexa core      1
# intel core i3 7th gen        1
# Name: count, Length: 61, dtype: int64

# %%
df['CPU_Rank'].value_counts()
# Out:
# CPU_Rank
# 108    224
# 362    139
# 87      88
# 540     76
# 61      75
# 187     60
# 64      58
# 745     31
# 48      27
# 560     25
# 330     25
# 97      24
# 38      16
# 148     11
# 873     10
# 24      10
# 110      8
# 579      7
# 75       6
# 45       6
# 4        5
# 674      5
# 69       5
# 206      4
# 167      4
# 590      4
# 109      3
# 123      2
# 180      2
# 767      2
# 707      2
# 880      2
# 907      2
# 58       1
# 331      1
# 70       1
# 352      1
# 77       1
# 36       1
# 676      1
# 34       1
# 342      1
# 63       1
# 428      1
# 74       1
# 113      1
# 178      1
# 530      1
# Name: count, dtype: int64

# %%
df['Battery_Lifetime_in_Hrs'].value_counts()
# Out:
# Battery_Lifetime_in_Hrs
# 4.5    688
# 4.0    231
# 5.0     64
# Name: count, dtype: int64

# %%
pie_plot(features=df['Battery_Lifetime_in_Hrs'])

# %%
df['GPU'].value_counts()
# Out:
# GPU
# intel uhd                           248
# intel iris xe                       134
# amd radeon                          123
# intel hd                             68
# nvidia geforce rtx 3050              67
#                                    ...
# amd radeon rx6600m                    1
# amd radeon rx 6700m                   1
# nvidia geforce rtx 2060               1
# nvidia geforce gtx 1650 ti max-q      1
# qualcomm adreno                       1
# Name: count, Length: 61, dtype: int64

# %%
df['GPU_Benchmark_Score'].value_counts()
# Out:
# GPU_Benchmark_Score
# 5.05      248
# 17.50     178
# 102.00    123
# 4.23       69
# 72.60      67
# 59.90      64
# 132.00     40
# 59.00      30
# 33.80      19
# 10.60      17
# 41.80      13
# 33.00      12
# 16.50      12
# 1.53       11
# 154.00      9
# 83.30       7
# 168.00      6
# 3.07        5
# 4.82        5
# 70.90       4
# 10.90       4
# 36.40       3
# 70.20       3
# 7.00        2
# 2.13        2
# 78.40       2
# 3.50        2
# 76.50       2
# 6.00        2
# 1.00        2
# 14.50       2
# 109.00      1
# 3.71        1
# 93.90       1
# 18.00       1
# 233.00      1
# 9.95        1
# 6.33        1
# 1.87        1
# 17.00       1
# 10.40       1
# 36.00       1
# 93.70       1
# 4.61        1
# 6.80        1
# 42.60       1
# 78.10       1
# 88.70       1
# 42.00       1
# Name: count, dtype: int64

# %%
df['RAM_Type_Tokenized'].value_counts()
# Out:
# RAM_Type_Tokenized
# 4    855
# 6     86
# 7     20
# 5     14
# 8      5
# 2      2
# 1      1
# Name: count, dtype: int64

# %%
df['GPU_Processor_Tokenized'].value_counts()
# Out:
# GPU_Processor_Tokenized
# 7     248
# 8     134
# 5     123
# 3      68
# 2      67
#      ...
# 35      1
# 29      1
# 48      1
# 54      1
# 19      1
# Name: count, Length: 62, dtype: int64

# %% [markdown]
# ## Recommendation System - Content-Based Filtering

# %%
# method 1 rekomendasi ketika user memilih laptop atau ketika suatu laptop terdisplay (index)
# method 2 ketika user memilih feature (seperti nama laptop, atau spek ram atau storage)

# %%
df['Laptop_Full_Description'] = df['Laptop_Name'] + ' ' + df['Laptop_Type'] + ' ' + str(df['Storage_Capacity']) + 'GB ' + df['Storage_Type'] + ' ' + df['Memory_Type'] + ' ' + str(df['RAM_in_GB']) + 'GB '+ df['RAM_Type'] + ' ' + df['Processor'] + ' ' + df['GPU'] + str(df['Refresh_Rate']) +'Hz '+ str(df['Weight_in_Kg']) + 'Kg ' + str(df['Screen_Size_in_Inch']) + 'Inch ' + df['Touchscreen_Features'] + ' ' + df['OS'] + ' ' + str(df['Price_in_IDR']) + ' Rupiah'

# %%
df_vectorize = df[['Laptop_Index', 'Laptop_Full_Description']]

df_vectorize
# Out:
#      Laptop_Index                            Laptop_Full_Description
# 0               1  acer aspire 3 gen_type(1) Thin and Light Lapto...
# 1               2  acer aspire 3 gen_type(2) Thin and Light Lapto...
# 2               3  acer aspire 3 gen_type(1) Notebook 0       256...
# 3               4  acer aspire 3 gen_type(1) Thin and Light Lapto...
# 4               5  acer aspire 3 gen_type(2) Thin and Light Lapto...
# ..            ...                                                ...
# 978           979  vaio e series 3500u_type(1) Thin and Light Lap...
# 979           980  vaio e series 3500u_type(2) Thin and Light Lap...
# 980           981  vaio e series 3700u_type(1) Thin and Light Lap...
# 981           982  vaio e series 3700u_type(2) Thin and Light Lap...
# 982           983  vaio se series gen_type(1) Thin and Light Lapt...
#
# [983 rows x 2 columns]

# %% [markdown]
# #### Vectorizing and Cosine Similarity

# %% [markdown]
# ###### method 1 - based on selected indexing (all feature)

# %%
cv = CountVectorizer()

laptop_vector = cv.fit_transform(df_vectorize['Laptop_Full_Description'])
laptop_vector.shape
# Out:
# (983, 438)

# %%
laptop_similarity = cosine_similarity(laptop_vector)
laptop_similarity
# Out:
# array([[1.        , 0.99922451, 0.9859387 , ..., 0.98058238, 0.98058238,
#         0.98990646],
#        [0.99922451, 1.        , 0.98519844, ..., 0.98139653, 0.98139653,
#         0.99069887],
#        [0.9859387 , 0.98519844, 1.        , ..., 0.97433352, 0.97433352,
#         0.98211574],
#        ...,
#        [0.98058238, 0.98139653, 0.97433352, ..., 1.        , 1.        ,
#         0.98297214],
#        [0.98058238, 0.98139653, 0.97433352, ..., 1.        , 1.        ,
#         0.98297214],
#        [0.98990646, 0.99069887, 0.98211574, ..., 0.98297214, 0.98297214,
#         1.        ]])

# %%
laptop_similarity.shape
# Out:
# (983, 983)

# %%
def indexing_recommendation(laptop, display_num: int=10):
    index = df_vectorize[df_vectorize['Laptop_Index'] == laptop.index[0]].index[0]
    distances = laptop_similarity[index]
    recommendation_list = sorted(list(enumerate(distances)), reverse=True, key=lambda x:x[1])[1:display_num+1]

    return recommendation_list

# %%
index_parsing = df[df.index == 1]
index_parsing
# Out:
#    Laptop_Index                                    Link_References  \
# 1             2  https://www.flipkart.com/acer-aspire-3-core-i3...
#
#                  Laptop_Name  User_Rating  Price_in_IDR  \
# 1  acer aspire 3 gen_type(2)          0.0       7338698
#
#              Laptop_Type  Dedicated_GPU_in_GB Processor_Brand Storage_Type  \
# 1  Thin and Light Laptop                    0           Intel          SSD
#
#    RAM_in_GB  ... Storage_Capacity               Processor CPU_Rank  \
# 1          8  ...              512  intel core i3 11th gen      362
#
#   Battery_Lifetime_in_Hrs        GPU  GPU_Benchmark_Score  RAM_Type_Tokenized  \
# 1                     4.5  intel uhd                 5.05                   4
#
#    GPU_Processor_Tokenized                                         Image_Link  \
# 1                        7  https://rukminim2.flixcart.com/image/416/416/l...
#
#                              Laptop_Full_Description
# 1  acer aspire 3 gen_type(2) Thin and Light Lapto...
#
# [1 rows x 29 columns]

# %%
display(Image(url=index_parsing['Image_Link'].values[0], width=300, height=300))
# Out:
# <img src="https://rukminim2.flixcart.com/image/416/416/l5h2xe80/screen-guard/screen-guard/t/u/j/acer-aspire-3-intel-core-i3-15-6-inch-inch-screen-guards-original-imagg4zyxxuwqfhv.jpeg?q=70&crop=false" width="300" height="300"/>

# %%
index_recom = indexing_recommendation(laptop=index_parsing, display_num=5)

for i in index_recom:
    print(df.iloc[i[0]])
    print('-' * 50)
# Out:
# Laptop_Index                                                               2
# Link_References            https://www.flipkart.com/acer-aspire-3-core-i3...
# Laptop_Name                                        acer aspire 3 gen_type(2)
# User_Rating                                                              0.0
# Price_in_IDR                                                         7338698
# Laptop_Type                                            Thin and Light Laptop
# Dedicated_GPU_in_GB                                                        0
# Processor_Brand                                                        Intel
# Storage_Type                                                             SSD
# RAM_in_GB                                                                  8
# RAM_Type                                                                ddr4
# Memory_Type                                                   Non Expandable
# OS                                                                   Windows
# Touchscreen_Features                                         Non Touchscreen
# Screen_Size_in_Inch                                                     15.6
# Weight_in_Kg                                                             1.7
# Refresh_Rate                                                              60
# Screen_Resolution                                                       1080
# Laptop_Company                                                          Acer
# Storage_Capacity                                                         512
# Processor                                             intel core i3 11th gen
# CPU_Rank                                                                 362
# Battery_Lifetime_in_Hrs                                                  4.5
# GPU                                                                intel uhd
# GPU_Benchmark_Score                                                     5.05
# RAM_Type_Tokenized                                                         4
# GPU_Processor_Tokenized                                                    7
# Image_Link                 https://rukminim2.flixcart.com/image/416/416/l...
# Laptop_Full_Description    acer aspire 3 gen_type(2) Thin and Light Lapto...
# Name: 1, dtype: object
# --------------------------------------------------
# Laptop_Index                                                              58
# Link_References            https://www.flipkart.com/acer-travelmate-core-...
# Laptop_Name                                      acer travelmate gen_type(1)
# User_Rating                                                              4.2
# Price_in_IDR                                                         8185688
# Laptop_Type                                            Thin and Light Laptop
# Dedicated_GPU_in_GB                                                        0
# Processor_Brand                                                        Intel
# Storage_Type                                                             SSD
# RAM_in_GB                                                                  8
# RAM_Type                                                                ddr4
# Memory_Type                                                       Expandable
# OS                                                                   Windows
# Touchscreen_Features                                         Non Touchscreen
# Screen_Size_in_Inch                                                     14.0
# Weight_in_Kg                                                            1.68
# Refresh_Rate                                                              60
# Screen_Resolution                                                       1080
# Laptop_Company                                                          Acer
# Storage_Capacity                                                        1256
# Processor                                             intel core i3 11th gen
# CPU_Rank                                                                 362
# Battery_Lifetime_in_Hrs                                                  4.5
# GPU                                                                intel uhd
# GPU_Benchmark_Score                                                     5.05
# RAM_Type_Tokenized                                                         4
# GPU_Processor_Tokenized                                                    7
# Image_Link                 https://rukminim2.flixcart.com/image/416/416/k...
# Laptop_Full_Description    acer travelmate gen_type(1) Thin and Light Lap...
# Name: 57, dtype: object
# --------------------------------------------------
# Laptop_Index                                                             593
# Link_References            https://www.flipkart.com/hp-core-i3-11th-gen-8...
# Laptop_Name                                                   hp gen_type(4)
# User_Rating                                                              4.2
# Price_in_IDR                                                         8355086
# Laptop_Type                                            Thin and Light Laptop
# Dedicated_GPU_in_GB                                                        0
# Processor_Brand                                                        Intel
# Storage_Type                                                             SSD
# RAM_in_GB                                                                  8
# RAM_Type                                                                ddr4
# Memory_Type                                                       Expandable
# OS                                                                   Windows
# Touchscreen_Features                                         Non Touchscreen
# Screen_Size_in_Inch                                                     14.0
# Weight_in_Kg                                                            1.46
# Refresh_Rate                                                              60
# Screen_Resolution                                                        720
# Laptop_Company                                                            HP
# Storage_Capacity                                                         256
# Processor                                             intel core i3 11th gen
# CPU_Rank                                                                 362
# Battery_Lifetime_in_Hrs                                                  4.5
# GPU                                                                intel uhd
# GPU_Benchmark_Score                                                     5.05
# RAM_Type_Tokenized                                                         4
# GPU_Processor_Tokenized                                                    7
# Image_Link                 https://rukminim2.flixcart.com/image/416/416/k...
# Laptop_Full_Description    hp gen_type(4) Thin and Light Laptop 0       2...
# Name: 592, dtype: object
# --------------------------------------------------
# Laptop_Index                                                             597
# Link_References            https://www.flipkart.com/hp-core-i3-11th-gen-8...
# Laptop_Name                                                   hp gen_type(8)
# User_Rating                                                              4.3
# Price_in_IDR                                                         8091578
# Laptop_Type                                            Thin and Light Laptop
# Dedicated_GPU_in_GB                                                        0
# Processor_Brand                                                        Intel
# Storage_Type                                                             SSD
# RAM_in_GB                                                                  8
# RAM_Type                                                                ddr4
# Memory_Type                                                       Expandable
# OS                                                                   Windows
# Touchscreen_Features                                         Non Touchscreen
# Screen_Size_in_Inch                                                     14.0
# Weight_in_Kg                                                            1.46
# Refresh_Rate                                                              60
# Screen_Resolution                                                       1080
# Laptop_Company                                                            HP
# Storage_Capacity                                                         512
# Processor                                             intel core i3 11th gen
# CPU_Rank                                                                 362
# Battery_Lifetime_in_Hrs                                                  4.5
# GPU                                                                intel uhd
# GPU_Benchmark_Score                                                     5.05
# RAM_Type_Tokenized                                                         4
# GPU_Processor_Tokenized                                                    7
# Image_Link                 https://rukminim2.flixcart.com/image/416/416/x...
# Laptop_Full_Description    hp gen_type(8) Thin and Light Laptop 0       2...
# Name: 596, dtype: object
# --------------------------------------------------
# Laptop_Index                                                              33
# Link_References            https://www.flipkart.com/acer-extensa-15-core-...
# Laptop_Name                                      acer extensa 15 gen_type(1)
# User_Rating                                                              4.3
# Price_in_IDR                                                         7056368
# Laptop_Type                                            Thin and Light Laptop
# Dedicated_GPU_in_GB                                                        0
# Processor_Brand                                                        Intel
# Storage_Type                                                             SSD
# RAM_in_GB                                                                  4
# RAM_Type                                                                ddr4
# Memory_Type                                                   Non Expandable
# OS                                                                   Windows
# Touchscreen_Features                                         Non Touchscreen
# Screen_Size_in_Inch                                                     15.6
# Weight_in_Kg                                                        1.500672
# Refresh_Rate                                                              60
# Screen_Resolution                                                       1080
# Laptop_Company                                                          Acer
# Storage_Capacity                                                         256
# Processor                                             intel core i3 11th gen
# CPU_Rank                                                                 362
# Battery_Lifetime_in_Hrs                                                  4.5
# GPU                                                                intel uhd
# GPU_Benchmark_Score                                                     5.05
# RAM_Type_Tokenized                                                         4
# GPU_Processor_Tokenized                                                    7
# Image_Link                 https://rukminim2.flixcart.com/image/416/416/k...
# Laptop_Full_Description    acer extensa 15 gen_type(1) Thin and Light Lap...
# Name: 32, dtype: object
# --------------------------------------------------

# %%
for laptop in index_recom:
    image_url = df.iloc[laptop[0]]['Image_Link'] 
    display(Image(url=image_url, width=300, height=300))
# Out:
# <img src="https://rukminim2.flixcart.com/image/416/416/l5h2xe80/screen-guard/screen-guard/t/u/j/acer-aspire-3-intel-core-i3-15-6-inch-inch-screen-guards-original-imagg4zyxxuwqfhv.jpeg?q=70&crop=false" width="300" height="300"/>
# <img src="https://rukminim2.flixcart.com/image/416/416/kr58yvk0/computer/1/f/i/na-business-laptop-acer-original-imag5y57uuuaya3u.jpeg?q=70&crop=false" width="300" height="300"/>
# <img src="https://rukminim2.flixcart.com/image/416/416/kp2y2kw0/computer/p/n/a/hp-original-imag3efeqfqqx6e5.jpeg?q=70&crop=false" width="300" height="300"/>
# <img src="https://rukminim2.flixcart.com/image/416/416/xif0q/computer/w/u/m/14s-dq2606tu-thin-and-light-laptop-hp-original-imah44pjndymfha3.jpeg?q=70&crop=false" width="300" height="300"/>
# <img src="https://rukminim2.flixcart.com/image/416/416/ku4ezrk0/computer/e/0/s/ex215-54-thin-and-light-laptop-acer-original-imag7bmpvdagbvep.jpeg?q=70&crop=false" width="300" height="300"/>

# %% [markdown]
# ###### method 2 - based on selected features

# %%
tfidf = TfidfVectorizer()

tfidf_matrix = tfidf.fit_transform(df_vectorize['Laptop_Full_Description'])
tfidf_matrix.shape
# Out:
# (983, 438)

# %%
def text_recommendation(input_text, num_display: int=10):
    if not isinstance(input_text, str):
        input_text = str(input_text)

    input_vector = tfidf.transform([input_text])
    cosine_sim = linear_kernel(input_vector, tfidf_matrix).flatten()
    
    similarity_score = sorted(enumerate(cosine_sim), key=lambda x: x[1], reverse=True)
    similarity_score = similarity_score[1:num_display+1]
    
    return similarity_score

# %%
search_text = 'AMD Ryzen'

text_recom = text_recommendation(input_text=search_text, num_display=5)

# %%
for i in text_recom:
    print(df.iloc[i[0]])
    print('-' * 50)
# Out:
# Laptop_Index                                                             692
# Link_References            https://www.flipkart.com/hp-ryzen-5-hexa-core-...
# Laptop_Name                                                  hp core_type(2)
# User_Rating                                                              4.3
# Price_in_IDR                                                         9032678
# Laptop_Type                                                         Notebook
# Dedicated_GPU_in_GB                                                        0
# Processor_Brand                                                          AMD
# Storage_Type                                                             SSD
# RAM_in_GB                                                                  8
# RAM_Type                                                                ddr4
# Memory_Type                                                   Non Expandable
# OS                                                                   Windows
# Touchscreen_Features                                         Non Touchscreen
# Screen_Size_in_Inch                                                     15.6
# Weight_in_Kg                                                        9.974375
# Refresh_Rate                                                              60
# Screen_Resolution                                                       1080
# Laptop_Company                                                            HP
# Storage_Capacity                                                         512
# Processor                                              amd ryzen 5 hexa core
# CPU_Rank                                                                  87
# Battery_Lifetime_in_Hrs                                                  4.5
# GPU                                                               amd radeon
# GPU_Benchmark_Score                                                    102.0
# RAM_Type_Tokenized                                                         4
# GPU_Processor_Tokenized                                                    5
# Image_Link                 https://rukminim2.flixcart.com/image/416/416/k...
# Laptop_Full_Description    hp core_type(2) Notebook 0       256\n1       ...
# Name: 691, dtype: object
# --------------------------------------------------
# Laptop_Index                                                             686
# Link_References            https://www.flipkart.com/hp-ryzen-3-dual-core-...
# Laptop_Name                                                  hp core_type(2)
# User_Rating                                                              0.0
# Price_in_IDR                                                         8317442
# Laptop_Type                                                         Notebook
# Dedicated_GPU_in_GB                                                        0
# Processor_Brand                                                          AMD
# Storage_Type                                                             SSD
# RAM_in_GB                                                                  8
# RAM_Type                                                                ddr4
# Memory_Type                                                   Non Expandable
# OS                                                                   Windows
# Touchscreen_Features                                         Non Touchscreen
# Screen_Size_in_Inch                                                     14.0
# Weight_in_Kg                                                        9.974375
# Refresh_Rate                                                              60
# Screen_Resolution                                                        720
# Laptop_Company                                                            HP
# Storage_Capacity                                                         512
# Processor                                              amd ryzen 3 dual core
# CPU_Rank                                                                 560
# Battery_Lifetime_in_Hrs                                                  4.5
# GPU                                                               amd radeon
# GPU_Benchmark_Score                                                    102.0
# RAM_Type_Tokenized                                                         4
# GPU_Processor_Tokenized                                                    5
# Image_Link                 https://rukminim2.flixcart.com/image/416/416/k...
# Laptop_Full_Description    hp core_type(2) Notebook 0       256\n1       ...
# Name: 685, dtype: object
# --------------------------------------------------
# Laptop_Index                                                             188
# Link_References            https://www.flipkart.com/asus-ryzen-5-hexa-cor...
# Laptop_Name                                               asus 5500u_type(1)
# User_Rating                                                              4.4
# Price_in_IDR                                                         8968683
# Laptop_Type                                            Thin and Light Laptop
# Dedicated_GPU_in_GB                                                        0
# Processor_Brand                                                          AMD
# Storage_Type                                                             SSD
# RAM_in_GB                                                                  8
# RAM_Type                                                                ddr4
# Memory_Type                                                   Non Expandable
# OS                                                                   Windows
# Touchscreen_Features                                         Non Touchscreen
# Screen_Size_in_Inch                                                     15.6
# Weight_in_Kg                                                             1.8
# Refresh_Rate                                                              60
# Screen_Resolution                                                       1080
# Laptop_Company                                                          Asus
# Storage_Capacity                                                         512
# Processor                                              amd ryzen 5 hexa core
# CPU_Rank                                                                  87
# Battery_Lifetime_in_Hrs                                                  4.5
# GPU                                                               amd radeon
# GPU_Benchmark_Score                                                    102.0
# RAM_Type_Tokenized                                                         4
# GPU_Processor_Tokenized                                                    5
# Image_Link                 https://rukminim2.flixcart.com/image/416/416/k...
# Laptop_Full_Description    asus 5500u_type(1) Thin and Light Laptop 0    ...
# Name: 187, dtype: object
# --------------------------------------------------
# Laptop_Index                                                             693
# Link_References            https://www.flipkart.com/hp-ryzen-5-hexa-core-...
# Laptop_Name                                                 hp 5500u_type(1)
# User_Rating                                                              4.3
# Price_in_IDR                                                         9691448
# Laptop_Type                                            Thin and Light Laptop
# Dedicated_GPU_in_GB                                                        0
# Processor_Brand                                                          AMD
# Storage_Type                                                             SSD
# RAM_in_GB                                                                  8
# RAM_Type                                                                ddr4
# Memory_Type                                                       Expandable
# OS                                                                   Windows
# Touchscreen_Features                                         Non Touchscreen
# Screen_Size_in_Inch                                                     15.6
# Weight_in_Kg                                                            1.69
# Refresh_Rate                                                              60
# Screen_Resolution                                                       1080
# Laptop_Company                                                            HP
# Storage_Capacity                                                         512
# Processor                                              amd ryzen 5 hexa core
# CPU_Rank                                                                  87
# Battery_Lifetime_in_Hrs                                                  4.5
# GPU                                                               amd radeon
# GPU_Benchmark_Score                                                    102.0
# RAM_Type_Tokenized                                                         4
# GPU_Processor_Tokenized                                                    5
# Image_Link                 https://rukminim2.flixcart.com/image/416/416/k...
# Laptop_Full_Description    hp 5500u_type(1) Thin and Light Laptop 0      ...
# Name: 692, dtype: object
# --------------------------------------------------
# Laptop_Index                                                             694
# Link_References            https://www.flipkart.com/hp-ryzen-5-hexa-core-...
# Laptop_Name                                                 hp 5500u_type(2)
# User_Rating                                                              4.4
# Price_in_IDR                                                         9032678
# Laptop_Type                                            Thin and Light Laptop
# Dedicated_GPU_in_GB                                                        0
# Processor_Brand                                                          AMD
# Storage_Type                                                             SSD
# RAM_in_GB                                                                  8
# RAM_Type                                                                ddr4
# Memory_Type                                                       Expandable
# OS                                                                   Windows
# Touchscreen_Features                                         Non Touchscreen
# Screen_Size_in_Inch                                                     14.0
# Weight_in_Kg                                                            1.46
# Refresh_Rate                                                              60
# Screen_Resolution                                                       1080
# Laptop_Company                                                            HP
# Storage_Capacity                                                         512
# Processor                                              amd ryzen 5 hexa core
# CPU_Rank                                                                  87
# Battery_Lifetime_in_Hrs                                                  4.5
# GPU                                                               amd radeon
# GPU_Benchmark_Score                                                    102.0
# RAM_Type_Tokenized                                                         4
# GPU_Processor_Tokenized                                                    5
# Image_Link                 https://rukminim2.flixcart.com/image/416/416/x...
# Laptop_Full_Description    hp 5500u_type(2) Thin and Light Laptop 0      ...
# Name: 693, dtype: object
# --------------------------------------------------

# %%
for laptop in text_recom:
    image_url = df.iloc[laptop[0]]['Image_Link'] 
    display(Image(url=image_url, width=300, height=300))
# Out:
# <img src="https://rukminim2.flixcart.com/image/416/416/kzhbfrk0/computer/z/m/p/ideapad-5-pro-laptop-lenovo-original-imagbh46dxx6hy9h.jpeg?q=70&crop=false" width="300" height="300"/>
# <img src="https://rukminim2.flixcart.com/image/416/416/ky4qgsw0/computer/j/f/5/240-g8-laptop-hp-original-imagaffva46zgucg.jpeg?q=70&crop=false" width="300" height="300"/>
# <img src="https://rukminim2.flixcart.com/image/416/416/klscivk0/computer/d/f/d/x415jf-ek522ts-thin-and-light-laptop-asus-original-imagyufa2sywf9ub.jpeg?q=70&crop=false" width="300" height="300"/>
# <img src="https://rukminim2.flixcart.com/image/416/416/k7531jk0/computer/e/a/h/hp-original-imafpfs893zu5mhb.jpeg?q=70&crop=false" width="300" height="300"/>
# <img src="https://rukminim2.flixcart.com/image/416/416/xif0q/computer/i/p/v/-original-imagykgquh7hsy5z.jpeg?q=70&crop=false" width="300" height="300"/>

# %% [markdown]
# ## Add On Filtering

# %%
df.columns
# Out:
# Index(['Laptop_Index', 'Link_References', 'Laptop_Name', 'User_Rating',
#        'Price_in_IDR', 'Laptop_Type', 'Dedicated_GPU_in_GB', 'Processor_Brand',
#        'Storage_Type', 'RAM_in_GB', 'RAM_Type', 'Memory_Type', 'OS',
#        'Touchscreen_Features', 'Screen_Size_in_Inch', 'Weight_in_Kg',
#        'Refresh_Rate', 'Screen_Resolution', 'Laptop_Company',
#        'Storage_Capacity', 'Processor', 'CPU_Rank', 'Battery_Lifetime_in_Hrs',
#        'GPU', 'GPU_Benchmark_Score', 'RAM_Type_Tokenized',
#        'GPU_Processor_Tokenized', 'Image_Link', 'Laptop_Full_Description'],
#       dtype='object')

# %%
df['Storage_Type'].unique()
# Out:
# array(['SSD', 'HDD'], dtype=object)

# %% [markdown]
# #### Normal Filtering based on Features

# %% [markdown]
# ###### by price ranges features

# %%
def filter_by_price(min_price=None, max_price=None, show_num: int=None, reversed: bool=False):
    filtered_df = df.copy()
    
    if min_price is not None:
        filtered_df = filtered_df[filtered_df['Price_in_IDR'] >= min_price]
    if max_price is not None:
        filtered_df = filtered_df[filtered_df['Price_in_IDR'] <= max_price]
    
    sorted_df = filtered_df.sort_values(by='Price_in_IDR', ascending=reversed)
    
    if show_num is not None:
        return sorted_df.head(show_num)
        
    return sorted_df

# %%
min_price = 5000000
max_price = 10000000

filter_by_price(min_price=min_price, max_price=max_price, show_num=5, reversed=False)
# Out:
#      Laptop_Index                                    Link_References  \
# 59             60  https://www.flipkart.com/acer-travelmate-core-...
# 820           821  https://www.flipkart.com/lenovo-ideapad-ryzen-...
# 223           224  https://www.flipkart.com/asus-vivobook-14-2021...
# 697           698  https://www.flipkart.com/hp-ryzen-5-quad-core-...
# 265           266  https://www.flipkart.com/asus-vivobook-15-core...
#
#                                Laptop_Name  User_Rating  Price_in_IDR  \
# 59             acer travelmate gen_type(2)          3.6       9973778
# 820           lenovo ideapad 5500u_type(1)          4.3       9973778
# 223  asus vivobook 14 (2021) 3700u_type(1)          4.7       9973778
# 697                       hp 3500u_type(1)          4.4       9973778
# 265           asus vivobook 15 gen_type(1)          4.5       9973778
#
#                Laptop_Type  Dedicated_GPU_in_GB Processor_Brand Storage_Type  \
# 59   Thin and Light Laptop                    0           Intel          SSD
# 820  Thin and Light Laptop                    0             AMD          SSD
# 223  Thin and Light Laptop                    0             AMD          SSD
# 697  Thin and Light Laptop                    0             AMD          SSD
# 265               Notebook                    0           Intel          SSD
#
#      RAM_in_GB  ... Storage_Capacity               Processor CPU_Rank  \
# 59           8  ...             1256  intel core i5 11th gen      108
# 820          8  ...              512   amd ryzen 5 hexa core       87
# 223         16  ...              512   amd ryzen 7 quad core       75
# 697          8  ...             1256   amd ryzen 5 quad core      330
# 265          8  ...              512  intel core i5 11th gen      108
#
#     Battery_Lifetime_in_Hrs                    GPU  GPU_Benchmark_Score  \
# 59                      4.5          intel iris xe                 17.5
# 820                     4.5             amd radeon                102.0
# 223                     4.5  amd radeon rx vega 10                 10.9
# 697                     4.5             amd radeon                102.0
# 265                     4.5          intel iris xe                 17.5
#
#      RAM_Type_Tokenized  GPU_Processor_Tokenized  \
# 59                    4                        8
# 820                   4                        5
# 223                   4                       15
# 697                   4                        5
# 265                   4                        8
#
#                                             Image_Link  \
# 59   https://rukminim2.flixcart.com/image/416/416/k...
# 820  https://rukminim2.flixcart.com/image/416/416/k...
# 223  https://rukminim2.flixcart.com/image/416/416/x...
# 697  https://rukminim2.flixcart.com/image/416/416/k...
# 265  https://rukminim2.flixcart.com/image/416/416/k...
#
#                                Laptop_Full_Description
# 59   acer travelmate gen_type(2) Thin and Light Lap...
# 820  lenovo ideapad 5500u_type(1) Thin and Light La...
# 223  asus vivobook 14 (2021) 3700u_type(1) Thin and...
# 697  hp 3500u_type(1) Thin and Light Laptop 0      ...
# 265  asus vivobook 15 gen_type(1) Notebook 0       ...
#
# [5 rows x 29 columns]

# %% [markdown]
# ###### by keywords arguments of choosen features

# %%
def filter_by_features(dataframe=None, display_num: int=None, **kwargs):
    if dataframe is not None:
        filtered_df = dataframe
    if dataframe is None:
        filtered_df = df.copy()
    column_map = {col.lower(): col for col in df.columns}

    valid_kwargs = {key: value for key, value in kwargs.items() if key.lower() not in {'display_num'}}
        
    for key, value in valid_kwargs.items():
        if key.lower() == 'price_in_idr':
            raise KeyError(f"Params '{key}' should not be use, instead change dataframe with filtered by price")
        if value is not None:
            normalized_key = column_map.get(key.lower())
            if normalized_key is None:
                raise KeyError(f"Column '{key}' not found in DataFrame")
            
            if isinstance(value, str):
                filtered_df = filtered_df[filtered_df[normalized_key].str.casefold() == value.casefold()]
            else:
                filtered_df = filtered_df[filtered_df[normalized_key] == value]
    
    if display_num is not None:
        return filtered_df.head(display_num)

    return filtered_df

# %%
features_option = {
    'User_Rating': None,
    'Laptop_Type': 'Notebook',
    'Processor_Brand': None,
    'Storage_Type': 'SSD',
    'Touchsreen_Features': None,
    'RAM_Type': None,
    'Memory_Type': None,
    'Laptop_Company': None,
    'GPU': None
}

filter_by_features(
    dataframe = filter_by_price(min_price=5000000, max_price=10000000),
    display_num = 5,
    **features_option           
)
# Out:
#      Laptop_Index                                    Link_References  \
# 265           266  https://www.flipkart.com/asus-vivobook-15-core...
# 696           697  https://www.flipkart.com/hp-ryzen-5-quad-core-...
# 516           517  https://www.flipkart.com/dell-ryzen-5-quad-cor...
# 422           423  https://www.flipkart.com/dell-inspiron-3511-co...
# 331           332  https://www.flipkart.com/asus-vivobook-ultra-k...
#
#                              Laptop_Name  User_Rating  Price_in_IDR  \
# 265         asus vivobook 15 gen_type(1)          4.5       9973778
# 696                      hp core_type(1)          0.0       9858964
# 516                    dell core_type(1)          4.3       9785558
# 422       dell inspiron 3511 gen_type(1)          3.8       9599032
# 331  asus vivobook ultra k15 gen_type(2)          5.0       9587927
#
#     Laptop_Type  Dedicated_GPU_in_GB Processor_Brand Storage_Type  RAM_in_GB  \
# 265    Notebook                    0           Intel          SSD          8
# 696    Notebook                    0             AMD          SSD          8
# 516    Notebook                    0             AMD          SSD          8
# 422    Notebook                    0           Intel          SSD         16
# 331    Notebook                    0           Intel          SSD          8
#
#      ... Storage_Capacity               Processor CPU_Rank  \
# 265  ...              512  intel core i5 11th gen      108
# 696  ...              512   amd ryzen 5 quad core      330
# 516  ...             1256   amd ryzen 5 quad core      330
# 422  ...             1256  intel core i3 11th gen      362
# 331  ...              512  intel core i3 11th gen      362
#
#     Battery_Lifetime_in_Hrs                GPU  GPU_Benchmark_Score  \
# 265                     4.5      intel iris xe                17.50
# 696                     4.5         amd radeon               102.00
# 516                     4.5  amd radeon vega 8                10.60
# 422                     4.5           intel hd                 4.23
# 331                     4.5          intel uhd                 5.05
#
#      RAM_Type_Tokenized  GPU_Processor_Tokenized  \
# 265                   4                        8
# 696                   4                        5
# 516                   4                       11
# 422                   4                        3
# 331                   4                        7
#
#                                             Image_Link  \
# 265  https://rukminim2.flixcart.com/image/416/416/k...
# 696  https://rukminim2.flixcart.com/image/416/416/l...
# 516  https://rukminim2.flixcart.com/image/416/416/k...
# 422  https://rukminim2.flixcart.com/image/416/416/k...
# 331  https://rukminim2.flixcart.com/image/416/416/k...
#
#                                Laptop_Full_Description
# 265  asus vivobook 15 gen_type(1) Notebook 0       ...
# 696  hp core_type(1) Notebook 0       256\n1       ...
# 516  dell core_type(1) Notebook 0       256\n1     ...
# 422  dell inspiron 3511 gen_type(1) Notebook 0     ...
# 331  asus vivobook ultra k15 gen_type(2) Notebook 0...
#
# [5 rows x 29 columns]

# %% [markdown]
# #### Top Rated based on Features

# %% [markdown]
# ###### by laptop type features

# %%
def rated_by_type(laptop_type: str, show_num: int=None, reversed: bool=False):
    filtered_df = df.copy()
    laptop_type = laptop_type.strip().upper()

    if laptop_type in df['Laptop_Type'].str.upper().unique():
        filtered_df = filtered_df[filtered_df['Laptop_Type'].str.upper() == laptop_type]
     
    sorted_df = filtered_df.sort_values(by='User_Rating', ascending=reversed)

    if show_num is not None:
        return sorted_df.head(show_num)

    return sorted_df

# %%
type_option = {
    1: 'Gaming Laptop',
    2: 'Thin and Light Laptop',
    3: '2 in 1 Laptop',
    4: 'Notebook'
}

rated_by_type(laptop_type=type_option[1])
# Out:
#      Laptop_Index                                    Link_References  \
# 140           141  https://www.flipkart.com/asus-rog-flow-x13-202...
# 172           173  https://www.flipkart.com/asus-rog-strix-scar-1...
# 175           176  https://www.flipkart.com/asus-rog-zephyrus-g14...
# 811           812  https://www.flipkart.com/lenovo-ideapad-gaming...
# 74             75  https://www.flipkart.com/asus-tuf-dash-f15-cor...
# ..            ...                                                ...
# 930           931  https://www.flipkart.com/msi-gp66-leopard-core...
# 936           937  https://www.flipkart.com/msi-katana-gf66-core-...
# 956           957  https://www.flipkart.com/msi-raider-ge66-core-...
# 958           959  https://www.flipkart.com/msi-stealth-gs66-core...
# 960           961  https://www.flipkart.com/msi-sword-15-core-i7-...
#
#                                  Laptop_Name  User_Rating  Price_in_IDR  \
# 140  asus rog flow x13 (2021) 5980hs_type(1)          5.0      45170918
# 172       asus rog strix scar 17 gen_type(1)          5.0      44229818
# 175                    asus rog zephyrus g14          5.0      15320920
# 811    lenovo ideapad gaming 3 5600h_type(2)          5.0      13173518
# 74        asus asus tuf dash f15 gen_type(1)          4.9      15996818
# ..                                       ...          ...           ...
# 930             msi gp66 leopard gen_type(2)          0.0      29789579
# 936              msi katana gf66 gen_type(2)          0.0      17879018
# 956              msi raider ge66 gen_type(1)          0.0      48935318
# 958             msi stealth gs66 gen_type(1)          0.0      52699718
# 960                 msi sword 15 gen_type(1)          0.0      16373258
#
#        Laptop_Type  Dedicated_GPU_in_GB Processor_Brand Storage_Type  \
# 140  Gaming Laptop                    4             AMD          SSD
# 172  Gaming Laptop                    8           Intel          SSD
# 175  Gaming Laptop                    4             AMD          SSD
# 811  Gaming Laptop                    4             AMD          SSD
# 74   Gaming Laptop                    6           Intel          SSD
# ..             ...                  ...             ...          ...
# 930  Gaming Laptop                    8           Intel          SSD
# 936  Gaming Laptop                    4           Intel          SSD
# 956  Gaming Laptop                    8           Intel          SSD
# 958  Gaming Laptop                    8           Intel          SSD
# 960  Gaming Laptop                    4           Intel          SSD
#
#      RAM_in_GB  ... Storage_Capacity                      Processor CPU_Rank  \
# 140         32  ...             1000          amd ryzen 9 octa core       48
# 172         32  ...             1000         intel core i9 12th gen        4
# 175          8  ...             1000  amd ryzen 7 octa core 4th gen      110
# 811          8  ...              512          amd ryzen 5 hexa core       87
# 74          16  ...              512         intel core i5 11th gen      108
# ..         ...  ...              ...                            ...      ...
# 930         16  ...             1000         intel core i7 11th gen       61
# 936         16  ...              512         intel core i7 11th gen       61
# 956         16  ...             1000         intel core i7 12th gen       38
# 958         32  ...             1000         intel core i7 12th gen       38
# 960          8  ...              512         intel core i7 11th gen       61
#
#     Battery_Lifetime_in_Hrs                         GPU  GPU_Benchmark_Score  \
# 140                     4.0     nvidia geforce gtx 1650                 59.9
# 172                     4.0  nvidia geforce rtx 3070 ti                168.0
# 175                     4.0     nvidia geforce gtx 1650                 59.9
# 811                     4.0     nvidia geforce rtx 3050                 72.6
# 74                      4.0     nvidia geforce rtx 3060                132.0
# ..                      ...                         ...                  ...
# 930                     4.0     nvidia geforce rtx 3070                154.0
# 936                     4.0  nvidia geforce rtx 3050 ti                 59.0
# 956                     4.0  nvidia geforce rtx 3070 ti                168.0
# 958                     4.0  nvidia geforce rtx 3070 ti                168.0
# 960                     4.0     nvidia geforce rtx 3050                 72.6
#
#      RAM_Type_Tokenized  GPU_Processor_Tokenized  \
# 140                   6                        6
# 172                   7                        1
# 175                   4                        6
# 811                   4                        2
# 74                    4                       12
# ..                  ...                      ...
# 930                   4                        9
# 936                   4                       10
# 956                   7                        1
# 958                   7                        1
# 960                   4                        2
#
#                                             Image_Link  \
# 140  https://rukminim2.flixcart.com/image/416/416/x...
# 172  https://rukminim2.flixcart.com/image/416/416/l...
# 175  https://rukminim2.flixcart.com/image/416/416/k...
# 811  https://rukminim2.flixcart.com/image/416/416/x...
# 74   https://rukminim2.flixcart.com/image/416/416/l...
# ..                                                 ...
# 930  https://rukminim2.flixcart.com/image/416/416/l...
# 936  https://rukminim2.flixcart.com/image/416/416/k...
# 956  https://rukminim2.flixcart.com/image/416/416/x...
# 958  https://rukminim2.flixcart.com/image/416/416/k...
# 960  https://rukminim2.flixcart.com/image/416/416/l...
#
#                                Laptop_Full_Description
# 140  asus rog flow x13 (2021) 5980hs_type(1) Gaming...
# 172  asus rog strix scar 17 gen_type(1) Gaming Lapt...
# 175  asus rog zephyrus g14 Gaming Laptop 0       25...
# 811  lenovo ideapad gaming 3 5600h_type(2) Gaming L...
# 74   asus asus tuf dash f15 gen_type(1) Gaming Lapt...
# ..                                                 ...
# 930  msi gp66 leopard gen_type(2) Gaming Laptop 0  ...
# 936  msi katana gf66 gen_type(2) Gaming Laptop 0   ...
# 956  msi raider ge66 gen_type(1) Gaming Laptop 0   ...
# 958  msi stealth gs66 gen_type(1) Gaming Laptop 0  ...
# 960  msi sword 15 gen_type(1) Gaming Laptop 0      ...
#
# [231 rows x 29 columns]

# %% [markdown]
# ###### by ranges price features

# %%
def rated_by_price(min_price=None, max_price=None, show_num: int=None, reversed: bool=False):
    filtered_df = df.copy()
    
    if min_price is not None:
        filtered_df = filtered_df[filtered_df['Price_in_IDR'] >= min_price]
    if max_price is not None:
        filtered_df = filtered_df[filtered_df['Price_in_IDR'] <= max_price]
    
    sorted_df = filtered_df.sort_values(by='User_Rating', ascending=reversed)
    
    if show_num is not None:
        return sorted_df.head(show_num)

    return sorted_df

# %%
min_price = 1000000
max_price = 5000000

rated_by_price(min_price=min_price, max_price=max_price)
# Out:
#      Laptop_Index                                    Link_References  \
# 369           370  https://www.flipkart.com/avita-satus-celeron-d...
# 370           371  https://www.flipkart.com/avita-satus-celeron-d...
# 128           129  https://www.flipkart.com/asus-eeebook-12-celer...
# 90             91  https://www.flipkart.com/asus-chromebook-celer...
# 94             95  https://www.flipkart.com/asus-chromebook-flip-...
# 221           222  https://www.flipkart.com/asus-vivobook-14-2021...
# 91             92  https://www.flipkart.com/asus-chromebook-celer...
# 5               6  https://www.flipkart.com/acer-aspire-3-dual-co...
# 89             90  https://www.flipkart.com/asus-chromebook-celer...
# 584           585  https://www.flipkart.com/hp-chromebook-mediate...
# 585           586  https://www.flipkart.com/hp-chromebook-mediate...
# 92             93  https://www.flipkart.com/asus-chromebook-celer...
# 719           720  https://www.flipkart.com/lenovo-apu-dual-core-...
# 754           755  https://www.flipkart.com/lenovo-ideapad-1-cele...
# 127           128  https://www.flipkart.com/asus-eeebook-12-celer...
# 368           369  https://www.flipkart.com/avita-pura-apu-dual-c...
# 93             94  https://www.flipkart.com/asus-chromebook-celer...
# 758           759  https://www.flipkart.com/lenovo-ideapad-3-chro...
# 88             89  https://www.flipkart.com/asus-chromebook-celer...
# 759           760  https://www.flipkart.com/lenovo-ideapad-3-chro...
# 28             29  https://www.flipkart.com/acer-celeron-dual-cor...
# 27             28  https://www.flipkart.com/acer-celeron-dual-cor...
# 86             87  https://www.flipkart.com/asus-celeron-dual-cor...
# 129           130  https://www.flipkart.com/asus-eeebook-12-celer...
#
#                                   Laptop_Name  User_Rating  Price_in_IDR  \
# 369                  avita satus core_type(1)          4.4       4138958
# 370                  avita satus core_type(2)          4.4       4138958
# 128              asus eeebook 12 core_type(2)          4.2       4138958
# 90               asus chromebook core_type(3)          4.1       4327178
# 94          asus chromebook flip core_type(1)          4.1       4138958
# 221      asus vivobook 14 (2021) core_type(1)          4.1       4891838
# 91               asus chromebook core_type(4)          4.0       4515398
# 5                 acer aspire 3 3020e_type(1)          3.9       4703618
# 89               asus chromebook core_type(2)          3.9       3762518
# 584                 hp chromebook 500_type(1)          3.8       3856628
# 585                 hp chromebook 500_type(2)          3.8       3762518
# 92               asus chromebook core_type(5)          3.8       3858322
# 719                     lenovo a99425_type(1)          3.8       4121265
# 754             lenovo ideapad 1 core_type(1)          3.7       4515398
# 127              asus eeebook 12 core_type(1)          3.7       3950738
# 368                     avita pura a6_type(1)          3.7       4044848
# 93               asus chromebook core_type(6)          3.6       3574298
# 758  lenovo ideapad 3 chromebook core_type(1)          3.5       3009638
# 88               asus chromebook core_type(1)          3.5       3762518
# 759   lenovo ideapad 3 chromebook gen_type(1)          2.8       4703618
# 28                          acer core_type(2)          0.0       4703618
# 27                          acer core_type(1)          0.0       4515398
# 86                          asus core_type(1)          0.0       4705312
# 129              asus eeebook 12 core_type(3)          0.0       4138958
#
#                Laptop_Type  Dedicated_GPU_in_GB Processor_Brand Storage_Type  \
# 369               Notebook                    0           Intel          SSD
# 370               Notebook                    0           Intel          SSD
# 128  Thin and Light Laptop                    0           Intel          HDD
# 90                Notebook                    0           Intel          HDD
# 94                Notebook                    0           Intel          HDD
# 221  Thin and Light Laptop                    0           Intel          SSD
# 91                Notebook                    0           Intel          HDD
# 5                 Notebook                    0             AMD          SSD
# 89                Notebook                    0           Intel          HDD
# 584               Notebook                    0        Mediatek          HDD
# 585               Notebook                    0        Mediatek          HDD
# 92                Notebook                    0           Intel          HDD
# 719  Thin and Light Laptop                    0             AMD          HDD
# 754  Thin and Light Laptop                    0           Intel          SSD
# 127  Thin and Light Laptop                    0           Intel          HDD
# 368  Thin and Light Laptop                    0             AMD          SSD
# 93                Notebook                    0           Intel          HDD
# 758               Notebook                    0           Intel          HDD
# 88                Notebook                    0           Intel          HDD
# 759               Notebook                    0           Intel          HDD
# 28   Thin and Light Laptop                    0           Intel          SSD
# 27   Thin and Light Laptop                    0           Intel          SSD
# 86                Notebook                    0           Intel          SSD
# 129  Thin and Light Laptop                    0           Intel          HDD
#
#      RAM_in_GB  ... Storage_Capacity                        Processor  \
# 369          4  ...              128          intel celeron dual core
# 370          4  ...              128          intel celeron dual core
# 128          4  ...               64          intel celeron dual core
# 90           4  ...               64          intel celeron dual core
# 94           4  ...               64          intel celeron dual core
# 221          4  ...              256          intel celeron dual core
# 91           4  ...               64          intel celeron dual core
# 5            4  ...              256                    amd dual core
# 89           4  ...               64          intel celeron dual core
# 584          4  ...               64   mediatek mediatek kompanio 500
# 585          4  ...               64   mediatek mediatek kompanio 500
# 92           4  ...               64          intel celeron dual core
# 719          4  ...             1000             amd apu dual core a9
# 754          4  ...              256          intel celeron dual core
# 127          4  ...               64          intel celeron dual core
# 368          4  ...              128             amd apu dual core a6
# 93           4  ...               64          intel celeron dual core
# 758          4  ...               64          intel celeron dual core
# 88           4  ...               32          intel celeron dual core
# 759          4  ...               64  intel celeron dual core 4th gen
# 28           4  ...              256          intel celeron dual core
# 27           4  ...              128          intel celeron dual core
# 86           4  ...              128          intel celeron dual core
# 129          4  ...               64          intel celeron dual core
#
#     CPU_Rank Battery_Lifetime_in_Hrs            GPU  GPU_Benchmark_Score  \
# 369      745                     4.5      intel uhd                 5.05
# 370      745                     4.5      intel uhd                 5.05
# 128      745                     4.5  intel uhd 600                 1.53
# 90       745                     4.5   intel hd 500                 3.07
# 94       745                     4.5  intel uhd 600                 1.53
# 221      745                     4.5      intel uhd                 5.05
# 91       745                     4.5   intel hd 500                 3.07
# 5        560                     4.5     amd radeon               102.00
# 89       745                     4.5   intel hd 500                 3.07
# 584      707                     4.5       mediatek                 1.00
# 585      707                     4.5       mediatek                 1.00
# 92       745                     4.5   intel hd 500                 3.07
# 719      590                     4.5     amd radeon               102.00
# 754      745                     4.5      intel uhd                 5.05
# 127      745                     4.5  intel uhd 600                 1.53
# 368      880                     4.5  amd radeon r4                 3.50
# 93       745                     4.5  intel uhd 600                 1.53
# 758      745                     4.5      intel uhd                 5.05
# 88       745                     4.5   intel hd 500                 3.07
# 759      907                     4.5      intel uhd                 5.05
# 28       745                     4.5  intel uhd 600                 1.53
# 27       745                     4.5  intel uhd 600                 1.53
# 86       745                     4.5      intel uhd                 5.05
# 129      745                     4.5  intel uhd 600                 1.53
#
#      RAM_Type_Tokenized  GPU_Processor_Tokenized  \
# 369                   4                        7
# 370                   4                        7
# 128                   4                       14
# 90                    5                       42
# 94                    5                       14
# 221                   4                        7
# 91                    5                       42
# 5                     4                        5
# 89                    5                       42
# 584                   4                       41
# 585                   6                       41
# 92                    5                       42
# 719                   4                        5
# 754                   4                        7
# 127                   4                       14
# 368                   4                       40
# 93                    5                       14
# 758                   5                        7
# 88                    5                       42
# 759                   5                        7
# 28                    4                       14
# 27                    4                       14
# 86                    4                        7
# 129                   4                       14
#
#                                             Image_Link  \
# 369  https://rukminim2.flixcart.com/image/416/416/l...
# 370  https://rukminim2.flixcart.com/image/416/416/l...
# 128  https://rukminim2.flixcart.com/image/416/416/x...
# 90   https://rukminim2.flixcart.com/image/416/416/x...
# 94   https://rukminim2.flixcart.com/image/416/416/x...
# 221  https://rukminim2.flixcart.com/image/416/416/x...
# 91   https://rukminim2.flixcart.com/image/416/416/x...
# 5    https://rukminim2.flixcart.com/image/416/416/x...
# 89   https://rukminim2.flixcart.com/image/416/416/x...
# 584  https://rukminim2.flixcart.com/image/416/416/x...
# 585  https://rukminim2.flixcart.com/image/416/416/x...
# 92   https://rukminim2.flixcart.com/image/416/416/k...
# 719  https://rukminim2.flixcart.com/image/416/416/x...
# 754  https://rukminim2.flixcart.com/image/416/416/x...
# 127  https://rukminim2.flixcart.com/image/416/416/l...
# 368  https://rukminim2.flixcart.com/image/416/416/k...
# 93   https://rukminim2.flixcart.com/image/416/416/x...
# 758  https://rukminim2.flixcart.com/image/416/416/x...
# 88   https://rukminim2.flixcart.com/image/416/416/x...
# 759  https://rukminim2.flixcart.com/image/416/416/k...
# 28   https://rukminim2.flixcart.com/image/416/416/l...
# 27   https://rukminim2.flixcart.com/image/416/416/l...
# 86   https://rukminim2.flixcart.com/image/416/416/x...
# 129  https://rukminim2.flixcart.com/image/416/416/l...
#
#                                Laptop_Full_Description
# 369  avita satus core_type(1) Notebook 0       256\...
# 370  avita satus core_type(2) Notebook 0       256\...
# 128  asus eeebook 12 core_type(2) Thin and Light La...
# 90   asus chromebook core_type(3) Notebook 0       ...
# 94   asus chromebook flip core_type(1) Notebook 0  ...
# 221  asus vivobook 14 (2021) core_type(1) Thin and ...
# 91   asus chromebook core_type(4) Notebook 0       ...
# 5    acer aspire 3 3020e_type(1) Notebook 0       2...
# 89   asus chromebook core_type(2) Notebook 0       ...
# 584  hp chromebook 500_type(1) Notebook 0       256...
# 585  hp chromebook 500_type(2) Notebook 0       256...
# 92   asus chromebook core_type(5) Notebook 0       ...
# 719  lenovo a99425_type(1) Thin and Light Laptop 0 ...
# 754  lenovo ideapad 1 core_type(1) Thin and Light L...
# 127  asus eeebook 12 core_type(1) Thin and Light La...
# 368  avita pura a6_type(1) Thin and Light Laptop 0 ...
# 93   asus chromebook core_type(6) Notebook 0       ...
# 758  lenovo ideapad 3 chromebook core_type(1) Noteb...
# 88   asus chromebook core_type(1) Notebook 0       ...
# 759  lenovo ideapad 3 chromebook gen_type(1) Notebo...
# 28   acer core_type(2) Thin and Light Laptop 0     ...
# 27   acer core_type(1) Thin and Light Laptop 0     ...
# 86   asus core_type(1) Notebook 0       256\n1     ...
# 129  asus eeebook 12 core_type(3) Thin and Light La...
#
# [24 rows x 29 columns]

# %% [markdown]
# ###### by processor brand features

# %%
def rated_by_processor(processor_brand: str, show_num: int=None, reversed: bool=False):
    filtered_df = df.copy()
    processor_brand = processor_brand.strip().upper()

    if processor_brand in df['Processor_Brand'].str.upper().unique():
        filtered_df = filtered_df[filtered_df['Processor_Brand'].str.upper() == processor_brand]
     
    sorted_df = filtered_df.sort_values(by='User_Rating', ascending=reversed)

    return sorted_df.head(show_num)

# %%
brand_option = {
    1: 'Intel',
    2: 'AMD',
    3: 'Qualcomm',
    4: 'Apple',
    5: 'Mediatek'
}

rated_by_processor(processor_brand=brand_option[4], show_num=5)
# Out:
#     Laptop_Index                                    Link_References  \
# 68            69  https://www.flipkart.com/apple-2021-macbook-pr...
# 60            61  https://www.flipkart.com/apple-2020-macbook-ai...
# 62            63  https://www.flipkart.com/apple-2020-macbook-ai...
# 61            62  https://www.flipkart.com/apple-2020-macbook-ai...
# 63            64  https://www.flipkart.com/apple-2020-macbook-ai...
#
#                     Laptop_Name  User_Rating  Price_in_IDR  \
# 68     2021 macbook pro_type(1)          4.8      42535838
# 60  2020 macbook air m1_type(1)          4.7      16561478
# 62  2020 macbook air m1_type(3)          4.7      19761218
# 61  2020 macbook air m1_type(2)          4.7      16561478
# 63  2020 macbook air m1_type(4)          4.7      19384778
#
#               Laptop_Type  Dedicated_GPU_in_GB Processor_Brand Storage_Type  \
# 68  Thin and Light Laptop                    0           Apple          SSD
# 60  Thin and Light Laptop                    0           Apple          SSD
# 62  Thin and Light Laptop                    0           Apple          SSD
# 61  Thin and Light Laptop                    0           Apple          SSD
# 63  Thin and Light Laptop                    0           Apple          SSD
#
#     RAM_in_GB  ... Storage_Capacity     Processor CPU_Rank  \
# 68         16  ...             1000  apple m1 pro       36
# 60          8  ...              256      apple m1      148
# 62          8  ...              512      apple m1      148
# 61          8  ...              256      apple m1      148
# 63          8  ...              512      apple m1      148
#
#    Battery_Lifetime_in_Hrs  GPU  GPU_Benchmark_Score  RAM_Type_Tokenized  \
# 68                     4.5   m1                 33.0                   8
# 60                     4.5   m1                 33.0                   4
# 62                     4.5   m1                 33.0                   4
# 61                     4.5   m1                 33.0                   4
# 63                     4.5   m1                 33.0                   4
#
#     GPU_Processor_Tokenized  \
# 68                       32
# 60                       32
# 62                       32
# 61                       32
# 63                       32
#
#                                            Image_Link  \
# 68  https://rukminim2.flixcart.com/image/416/416/k...
# 60  https://rukminim2.flixcart.com/image/416/416/k...
# 62  https://rukminim2.flixcart.com/image/416/416/k...
# 61  https://rukminim2.flixcart.com/image/416/416/k...
# 63  https://rukminim2.flixcart.com/image/416/416/k...
#
#                               Laptop_Full_Description
# 68  2021 macbook pro_type(1) Thin and Light Laptop...
# 60  2020 macbook air m1_type(1) Thin and Light Lap...
# 62  2020 macbook air m1_type(3) Thin and Light Lap...
# 61  2020 macbook air m1_type(2) Thin and Light Lap...
# 63  2020 macbook air m1_type(4) Thin and Light Lap...
#
# [5 rows x 29 columns]

# %% [markdown]
# ###### by laptop company features

# %%
def rated_by_company(laptop_company: str, show_num: int=None, reversed: bool=False):
    filtered_df = df.copy()
    laptop_company = laptop_company.strip().upper()

    if laptop_company in df['Laptop_Company'].str.upper().unique():
        filtered_df = filtered_df[filtered_df['Laptop_Company'].str.upper() == laptop_company]
     
    sorted_df = filtered_df.sort_values(by='User_Rating', ascending=reversed)

    if show_num is not None:
        return sorted_df.head(show_num)

    return sorted_df

# %%
company_option = {
    1: 'Asus',
    2: 'HP',
    3: 'Lenovo',
    4: 'Dell',
    5: 'MSI', 
    6: 'Realme',
    7: 'Avita',
    8: 'Acer',
    9: 'Samsung',
    10: 'Infinix',
    11: 'LG',
    12: 'Apple',
    13: 'Nokia',
    14: 'Redmibook',
    15: 'MI',
    16: 'VAIO'
}

rated_by_company(laptop_company=company_option[5], show_num=5)
# Out:
#      Laptop_Index                                    Link_References  \
# 908           909  https://www.flipkart.com/msi-alpha-15-ryzen-7-...
# 926           927  https://www.flipkart.com/msi-gf65-thin-hexa-co...
# 953           954  https://www.flipkart.com/msi-pulse-gl66-core-i...
# 955           956  https://www.flipkart.com/msi-pulse-gl66-core-i...
# 909           910  https://www.flipkart.com/msi-bravo-ryzen-5-hex...
#
#                     Laptop_Name  User_Rating  Price_in_IDR    Laptop_Type  \
# 908  msi alpha 15 5800h_type(1)          4.7      17879018  Gaming Laptop
# 926   msi gf65 thin gen_type(1)          4.6      14302838  Gaming Laptop
# 953  msi pulse gl66 gen_type(1)          4.6      21643418  Gaming Laptop
# 955  msi pulse gl66 gen_type(3)          4.6      20419988  Gaming Laptop
# 909     msi bravo 5600h_type(1)          4.5      13079408  Gaming Laptop
#
#      Dedicated_GPU_in_GB Processor_Brand Storage_Type  RAM_in_GB  ...  \
# 908                    8             AMD          SSD         16  ...
# 926                    6           Intel          SSD         16  ...
# 953                    6           Intel          SSD         16  ...
# 955                    4           Intel          SSD         16  ...
# 909                    4             AMD          SSD          8  ...
#
#     Storage_Capacity                    Processor CPU_Rank  \
# 908             1000        amd ryzen 7 octa core       64
# 926              512  intel hexa core i5 10th gen      109
# 953             1000       intel core i7 11th gen       61
# 955              512       intel core i7 11th gen       61
# 909              512        amd ryzen 5 hexa core       87
#
#     Battery_Lifetime_in_Hrs                         GPU  GPU_Benchmark_Score  \
# 908                     4.0          amd radeon rx6600m                 70.2
# 926                     4.0  nvidia geforce gtx 1660 ti                 76.5
# 953                     4.0     nvidia geforce rtx 3060                132.0
# 955                     4.0  nvidia geforce rtx 3050 ti                 59.0
# 909                     4.0            amd radeon 5500m                 42.6
#
#      RAM_Type_Tokenized  GPU_Processor_Tokenized  \
# 908                   4                       35
# 926                   4                       47
# 953                   4                       12
# 955                   4                       10
# 909                   4                       38
#
#                                             Image_Link  \
# 908  https://rukminim2.flixcart.com/image/416/416/k...
# 926  https://rukminim2.flixcart.com/image/416/416/k...
# 953  https://rukminim2.flixcart.com/image/416/416/k...
# 955  https://rukminim2.flixcart.com/image/416/416/k...
# 909  https://rukminim2.flixcart.com/image/416/416/x...
#
#                                Laptop_Full_Description
# 908  msi alpha 15 5800h_type(1) Gaming Laptop 0    ...
# 926  msi gf65 thin gen_type(1) Gaming Laptop 0     ...
# 953  msi pulse gl66 gen_type(1) Gaming Laptop 0    ...
# 955  msi pulse gl66 gen_type(3) Gaming Laptop 0    ...
# 909  msi bravo 5600h_type(1) Gaming Laptop 0       ...
#
# [5 rows x 29 columns]

# %% [markdown]
# ###### by memory type features

# %%
def rated_by_memory(storage_type: str, show_num: int=None, reversed: bool=False):
    filtered_df = df.copy()
    storage_type = storage_type.strip().upper()

    if storage_type == "HDD" or storage_type == "SSD":
        filtered_df = filtered_df[filtered_df['Storage_Type'] == storage_type]
     
    sorted_df = filtered_df.sort_values(by='User_Rating', ascending=reversed)

    if show_num is not None:
        return sorted_df.head(show_num)

    return sorted_df

# %%
memory_option = {
    1: 'HDD',
    2: 'SSD'
}

rated_by_memory(storage_type=memory_option[1], show_num=5)
# Out:
#      Laptop_Index                                    Link_References  \
# 977           978  https://www.flipkart.com/samsung-galaxy-book-g...
# 219           220  https://www.flipkart.com/asus-vivo-book-core-i...
# 128           129  https://www.flipkart.com/asus-eeebook-12-celer...
# 507           508  https://www.flipkart.com/dell-insprion-3501-co...
# 726           727  https://www.flipkart.com/lenovo-core-i3-10th-g...
#
#                           Laptop_Name  User_Rating  Price_in_IDR  \
# 977  samsung galaxy book go 2_type(1)          4.8       6962258
# 219        asus vivo book gen_type(1)          4.7       7152360
# 128      asus eeebook 12 core_type(2)          4.2       4138958
# 507    dell insprion 3501 gen_type(1)          4.2       8185688
# 726                lenovo gen_type(5)          4.2       7338698
#
#                Laptop_Type  Dedicated_GPU_in_GB Processor_Brand Storage_Type  \
# 977  Thin and Light Laptop                    0        Qualcomm          HDD
# 219               Notebook                    0           Intel          HDD
# 128  Thin and Light Laptop                    0           Intel          HDD
# 507               Notebook                    0           Intel          HDD
# 726               Notebook                    0           Intel          HDD
#
#      RAM_in_GB  ... Storage_Capacity                     Processor CPU_Rank  \
# 977          4  ...              128  qualcomm snapdragon 7c gen 2      590
# 219          4  ...             1000        intel core i3 10th gen      540
# 128          4  ...               64       intel celeron dual core      745
# 507          8  ...             1000        intel core i3 11th gen      362
# 726          8  ...             1000        intel core i3 10th gen      540
#
#     Battery_Lifetime_in_Hrs              GPU  GPU_Benchmark_Score  \
# 977                     4.5  qualcomm adreno                 6.00
# 219                     4.5         intel hd                 4.23
# 128                     4.5    intel uhd 600                 1.53
# 507                     4.5         intel hd                 4.23
# 726                     4.5        intel uhd                 5.05
#
#      RAM_Type_Tokenized  GPU_Processor_Tokenized  \
# 977                   6                       19
# 219                   4                        3
# 128                   4                       14
# 507                   4                        3
# 726                   4                        7
#
#                                             Image_Link  \
# 977  https://rukminim2.flixcart.com/image/416/416/l...
# 219  https://rukminim2.flixcart.com/image/416/416/k...
# 128  https://rukminim2.flixcart.com/image/416/416/x...
# 507  https://rukminim2.flixcart.com/image/416/416/k...
# 726  https://rukminim2.flixcart.com/image/416/416/l...
#
#                                Laptop_Full_Description
# 977  samsung galaxy book go 2_type(1) Thin and Ligh...
# 219  asus vivo book gen_type(1) Notebook 0       25...
# 128  asus eeebook 12 core_type(2) Thin and Light La...
# 507  dell insprion 3501 gen_type(1) Notebook 0     ...
# 726  lenovo gen_type(5) Notebook 0       256\n1    ...
#
# [5 rows x 29 columns]

# %% [markdown]
# ###### by combined features

# %%
def rated_by_fetures(min_price: int=None, max_price: int=None, laptop_type: str=None, storage_type: str=None, memory_type: str=None, laptop_company: str=None, processor_brand: str=None, show_num: int=None, reversed=False):
    filtered_df = df.copy()

    if laptop_type is not None:
        laptop_type = laptop_type.strip().upper()
        if laptop_type in df['Laptop_Type'].str.upper().unique():
            filtered_df = filtered_df[filtered_df['Laptop_Type'].str.upper() == laptop_type]

    if min_price is not None:
        filtered_df = filtered_df[filtered_df['Price_in_IDR'] >= min_price]
    if max_price is not None:
        filtered_df = filtered_df[filtered_df['Price_in_IDR'] <= max_price]

    if processor_brand is not None:
        processor_brand = processor_brand.strip().upper()
        if processor_brand in df['Processor_Brand'].str.upper().unique():
            filtered_df = filtered_df[filtered_df['Processor_Brand'].str.upper() == processor_brand]

    if storage_type is not None:
        storage_type = storage_type.strip().upper()
        if storage_type in df['Storage_Type'].str.upper().unique():
            filtered_df = filtered_df[filtered_df['Storage_Type'].str.upper() == storage_type]

    if memory_type is not None:
        memory_type = memory_type.strip().upper()
        if memory_type in df['Memory_Type'].str.upper().unique():
            filtered_df = filtered_df[filtered_df['Memory_Type'].str.upper() == memory_type]

    if laptop_company is not None:
        laptop_company = laptop_company.strip().upper()
        if laptop_company in df['Laptop_Company'].str.upper().unique():
            filtered_df = filtered_df[filtered_df['Laptop_Company'].str.upper() == laptop_company]

    sorted_df = filtered_df.sort_values(by='User_Rating', ascending=reversed)

    if show_num is not None:
        return sorted_df.head(show_num)

    return sorted_df

# %%
rated_by_fetures(laptop_type='Gaming Laptop', min_price=5000000, max_price=15000000, storage_type='SSD', show_num=5)
# Out:
#      Laptop_Index                                    Link_References  \
# 811           812  https://www.flipkart.com/lenovo-ideapad-gaming...
# 205           206  https://www.flipkart.com/asus-strix-g15-ryzen-...
# 212           213  https://www.flipkart.com/asus-tuf-gaming-f15-c...
# 512           513  https://www.flipkart.com/dell-ryzen-5-hexa-cor...
# 211           212  https://www.flipkart.com/asus-tuf-gaming-f15-c...
#
#                                Laptop_Name  User_Rating  Price_in_IDR  \
# 811  lenovo ideapad gaming 3 5600h_type(2)          5.0      13173518
# 205       asus strix g15 4800h gen_type(1)          4.7      14491058
# 212        asus tuf gaming f15 gen_type(3)          4.7      12232418
# 512                     dell 5600h_type(1)          4.7      13926398
# 211        asus tuf gaming f15 gen_type(2)          4.7      12232418
#
#        Laptop_Type  Dedicated_GPU_in_GB Processor_Brand Storage_Type  \
# 811  Gaming Laptop                    4             AMD          SSD
# 205  Gaming Laptop                    4             AMD          SSD
# 212  Gaming Laptop                    4           Intel          SSD
# 512  Gaming Laptop                    4             AMD          SSD
# 211  Gaming Laptop                    4           Intel          SSD
#
#      RAM_in_GB  ... Storage_Capacity                      Processor CPU_Rank  \
# 811          8  ...              512          amd ryzen 5 hexa core       87
# 205          8  ...              512  amd ryzen 7 octa core 4th gen      110
# 212          8  ...             1000         intel core i5 10th gen      187
# 512         16  ...              512          amd ryzen 5 hexa core       87
# 211          8  ...             1000         intel core i5 10th gen      187
#
#     Battery_Lifetime_in_Hrs                      GPU  GPU_Benchmark_Score  \
# 811                     4.0  nvidia geforce rtx 3050                 72.6
# 205                     4.0  nvidia geforce gtx 1650                 59.9
# 212                     4.0  nvidia geforce gtx 1650                 59.9
# 512                     4.0  nvidia geforce rtx 3050                 72.6
# 211                     4.0  nvidia geforce gtx 1650                 59.9
#
#      RAM_Type_Tokenized  GPU_Processor_Tokenized  \
# 811                   4                        2
# 205                   4                        6
# 212                   4                        6
# 512                   4                        2
# 211                   4                        6
#
#                                             Image_Link  \
# 811  https://rukminim2.flixcart.com/image/416/416/x...
# 205  https://rukminim2.flixcart.com/image/416/416/k...
# 212  https://rukminim2.flixcart.com/image/416/416/l...
# 512  https://rukminim2.flixcart.com/image/416/416/l...
# 211  https://rukminim2.flixcart.com/image/416/416/l...
#
#                                Laptop_Full_Description
# 811  lenovo ideapad gaming 3 5600h_type(2) Gaming L...
# 205  asus strix g15 4800h gen_type(1) Gaming Laptop...
# 212  asus tuf gaming f15 gen_type(3) Gaming Laptop ...
# 512  dell 5600h_type(1) Gaming Laptop 0       256\n...
# 211  asus tuf gaming f15 gen_type(2) Gaming Laptop ...
#
# [5 rows x 29 columns]
